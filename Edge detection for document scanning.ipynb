# %%
import cv2
import numpy as np

# %%
doc = cv2.imread("note_detection.jpg")


#Step 1 Resize the image to desired size
doc = cv2.resize(doc,(600,400))
original = doc.copy()

# %%
#Step2 Convert the image to greyscale
doc = cv2.cvtColor(doc,cv2.COLOR_BGR2GRAY)
# cv2.imshow("Grayscale",doc)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
#Step3 Apply Gaussian blur for better edge detection
doc = cv2.GaussianBlur(doc,(5,5),0)
# cv2.imshow("GuassianBlur",doc)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
#Step 4 Apply canny filter
canny = cv2.Canny(doc,100,120)
# cv2.imshow("Canny",canny)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
#Step5 Drawing countour boundary
contours,heriarchy = cv2.findContours(canny,cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)

print("Countours found are : " +str(len(contours)))

# Draw all contours
# Use '-1' as the 3rd parameter to draw all
cv2.drawContours(original, contours, -1, (255,0,0), 3)
cv2.imshow('Contours', original)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Countours found are : 14

# %%
contours
# Out:
# [array([[[ 28, 393]],
#
#         [[ 28, 394]],
#
#         [[ 29, 395]],
#
#         [[ 30, 395]],
#
#         [[ 31, 395]],
#
#         [[ 32, 395]],
#
#         [[ 33, 396]],
#
#         [[ 34, 396]],
#
#         [[ 35, 396]],
#
#         [[ 36, 397]],
#
#         [[ 37, 397]],
#
#         [[ 38, 398]],
#
#         [[ 39, 398]],
#
#         [[ 38, 397]],
#
#         [[ 37, 397]],
#
#         [[ 36, 396]],
#
#         [[ 35, 396]],
#
#         [[ 34, 396]],
#
#         [[ 33, 396]],
#
#         [[ 32, 395]],
#
#         [[ 31, 395]],
#
#         [[ 30, 395]],
#
#         [[ 29, 394]]], dtype=int32),
#  array([[[ 31, 392]],
#
#         [[ 32, 393]],
#
#         [[ 33, 393]],
#
#         [[ 32, 392]]], dtype=int32),
#  array([[[ 15, 389]],
#
#         [[ 16, 389]],
#
#         [[ 17, 389]],
#
#         [[ 18, 390]],
#
#         [[ 19, 390]],
#
#         [[ 20, 391]],
#
#         [[ 21, 391]],
#
#         [[ 20, 391]],
#
#         [[ 19, 390]],
#
#         [[ 18, 390]],
#
#         [[ 17, 389]],
#
#         [[ 16, 389]]], dtype=int32),
#  array([[[307, 360]]], dtype=int32),
#  array([[[586, 347]],
#
#         [[587, 348]],
#
#         [[588, 348]],
#
#         [[589, 348]],
#
#         [[590, 349]],
#
#         [[591, 350]],
#
#         [[592, 350]],
#
#         [[593, 350]],
#
#         [[594, 350]],
#
#         [[595, 351]],
#
#         [[596, 351]],
#
#         [[595, 351]],
#
#         [[594, 350]],
#
#         [[593, 350]],
#
#         [[592, 350]],
#
#         [[591, 349]],
#
#         [[590, 349]],
#
#         [[589, 348]],
#
#         [[588, 348]],
#
#         [[587, 348]]], dtype=int32),
#  array([[[327, 330]],
#
#         [[326, 331]],
#
#         [[325, 332]],
#
#         [[324, 333]],
#
#         [[323, 334]],
#
#         [[322, 335]],
#
#         [[321, 335]],
#
#         [[320, 336]],
#
#         [[319, 337]],
#
#         [[318, 337]],
#
#         [[317, 336]],
#
#         [[318, 337]],
#
#         [[319, 337]],
#
#         [[320, 338]],
#
#         [[320, 339]],
#
#         [[321, 340]],
#
#         [[322, 340]],
#
#         [[323, 341]],
#
#         [[324, 341]],
#
#         [[325, 341]],
#
#         [[326, 342]],
#
#         [[327, 342]],
#
#         [[328, 342]],
#
#         [[329, 342]],
#
#         [[330, 342]],
#
#         [[331, 342]],
#
#         [[332, 341]],
#
#         [[333, 341]],
#
#         [[334, 341]],
#
#         [[335, 341]],
#
#         [[336, 341]],
#
#         [[337, 340]],
#
#         [[338, 340]],
#
#         [[339, 339]],
#
#         [[340, 338]],
#
#         [[339, 337]],
#
#         [[339, 336]],
#
#         [[338, 335]],
#
#         [[337, 334]],
#
#         [[336, 333]],
#
#         [[335, 332]],
#
#         [[334, 332]],
#
#         [[333, 331]],
#
#         [[332, 330]],
#
#         [[331, 330]],
#
#         [[332, 331]],
#
#         [[333, 332]],
#
#         [[334, 332]],
#
#         [[335, 333]],
#
#         [[336, 334]],
#
#         [[337, 335]],
#
#         [[338, 336]],
#
#         [[339, 337]],
#
#         [[339, 338]],
#
#         [[338, 339]],
#
#         [[337, 340]],
#
#         [[336, 340]],
#
#         [[335, 341]],
#
#         [[334, 341]],
#
#         [[333, 341]],
#
#         [[332, 341]],
#
#         [[331, 342]],
#
#         [[330, 342]],
#
#         [[329, 342]],
#
#         [[328, 342]],
#
#         [[327, 342]],
#
#         [[326, 342]],
#
#         [[325, 341]],
#
#         [[324, 341]],
#
#         [[323, 341]],
#
#         [[322, 340]],
#
#         [[321, 339]],
#
#         [[320, 338]],
#
#         [[320, 337]],
#
#         [[321, 336]],
#
#         [[322, 335]],
#
#         [[323, 334]],
#
#         [[324, 334]],
#
#         [[325, 333]],
#
#         [[326, 332]],
#
#         [[327, 331]],
#
#         [[328, 330]],
#
#         [[329, 330]],
#
#         [[328, 330]]], dtype=int32),
#  array([[[  0, 318]],
#
#         [[  1, 318]],
#
#         [[  2, 318]],
#
#         [[  3, 318]],
#
#         [[  4, 319]],
#
#         [[  5, 319]],
#
#         [[  6, 320]],
#
#         [[  7, 320]],
#
#         [[  8, 320]],
#
#         [[  9, 321]],
#
#         [[ 10, 321]],
#
#         [[ 11, 321]],
#
#         [[ 12, 322]],
#
#         [[ 13, 322]],
#
#         [[ 14, 322]],
#
#         [[ 15, 322]],
#
#         [[ 16, 323]],
#
#         [[ 17, 323]],
#
#         [[ 18, 324]],
#
#         [[ 19, 324]],
#
#         [[ 20, 324]],
#
#         [[ 21, 325]],
#
#         [[ 22, 325]],
#
#         [[ 23, 325]],
#
#         [[ 24, 326]],
#
#         [[ 25, 326]],
#
#         [[ 26, 326]],
#
#         [[ 27, 327]],
#
#         [[ 28, 327]],
#
#         [[ 29, 328]],
#
#         [[ 30, 328]],
#
#         [[ 31, 328]],
#
#         [[ 32, 329]],
#
#         [[ 33, 329]],
#
#         [[ 34, 329]],
#
#         [[ 35, 330]],
#
#         [[ 34, 329]],
#
#         [[ 33, 329]],
#
#         [[ 32, 329]],
#
#         [[ 31, 328]],
#
#         [[ 30, 328]],
#
#         [[ 29, 327]],
#
#         [[ 28, 327]],
#
#         [[ 27, 327]],
#
#         [[ 26, 326]],
#
#         [[ 25, 326]],
#
#         [[ 24, 325]],
#
#         [[ 23, 325]],
#
#         [[ 22, 325]],
#
#         [[ 21, 325]],
#
#         [[ 20, 324]],
#
#         [[ 19, 324]],
#
#         [[ 18, 324]],
#
#         [[ 17, 323]],
#
#         [[ 16, 323]],
#
#         [[ 15, 322]],
#
#         [[ 14, 322]],
#
#         [[ 13, 322]],
#
#         [[ 12, 322]],
#
#         [[ 11, 321]],
#
#         [[ 10, 321]],
#
#         [[  9, 320]],
#
#         [[  8, 320]],
#
#         [[  7, 320]],
#
#         [[  6, 320]],
#
#         [[  5, 319]],
#
#         [[  4, 319]],
#
#         [[  3, 318]],
#
#         [[  2, 318]],
#
#         [[  1, 318]]], dtype=int32),
#  array([[[327, 314]],
#
#         [[326, 315]],
#
#         [[325, 315]],
#
#         [[324, 315]],
#
#         [[323, 315]],
#
#         [[322, 316]],
#
#         [[321, 316]],
#
#         [[320, 317]],
#
#         [[319, 317]],
#
#         [[318, 318]],
#
#         [[317, 319]],
#
#         [[316, 320]],
#
#         [[316, 321]],
#
#         [[315, 322]],
#
#         [[315, 323]],
#
#         [[315, 324]],
#
#         [[314, 325]],
#
#         [[315, 324]],
#
#         [[315, 323]],
#
#         [[316, 322]],
#
#         [[316, 321]],
#
#         [[317, 320]],
#
#         [[318, 319]],
#
#         [[319, 318]],
#
#         [[320, 317]],
#
#         [[321, 317]],
#
#         [[322, 316]],
#
#         [[323, 316]],
#
#         [[324, 315]],
#
#         [[325, 315]],
#
#         [[326, 315]],
#
#         [[327, 314]],
#
#         [[328, 314]],
#
#         [[329, 314]],
#
#         [[330, 314]],
#
#         [[331, 314]],
#
#         [[332, 314]],
#
#         [[333, 314]],
#
#         [[334, 315]],
#
#         [[335, 315]],
#
#         [[336, 316]],
#
#         [[337, 316]],
#
#         [[338, 317]],
#
#         [[339, 318]],
#
#         [[340, 318]],
#
#         [[341, 319]],
#
#         [[342, 320]],
#
#         [[342, 321]],
#
#         [[342, 322]],
#
#         [[341, 323]],
#
#         [[340, 324]],
#
#         [[339, 324]],
#
#         [[338, 324]],
#
#         [[337, 325]],
#
#         [[336, 325]],
#
#         [[335, 325]],
#
#         [[334, 326]],
#
#         [[333, 326]],
#
#         [[332, 326]],
#
#         [[331, 327]],
#
#         [[330, 327]],
#
#         [[329, 327]],
#
#         [[328, 327]],
#
#         [[327, 327]],
#
#         [[326, 327]],
#
#         [[325, 327]],
#
#         [[324, 327]],
#
#         [[323, 327]],
#
#         [[322, 327]],
#
#         [[321, 328]],
#
#         [[320, 328]],
#
#         [[319, 328]],
#
#         [[318, 328]],
#
#         [[317, 328]],
#
#         [[318, 328]],
#
#         [[319, 328]],
#
#         [[320, 328]],
#
#         [[321, 328]],
#
#         [[322, 327]],
#
#         [[323, 327]],
#
#         [[324, 327]],
#
#         [[325, 327]],
#
#         [[326, 327]],
#
#         [[327, 327]],
#
#         [[328, 327]],
#
#         [[329, 327]],
#
#         [[330, 327]],
#
#         [[331, 327]],
#
#         [[332, 327]],
#
#         [[333, 326]],
#
#         [[334, 326]],
#
#         [[335, 326]],
#
#         [[336, 325]],
#
#         [[337, 325]],
#
#         [[338, 324]],
#
#         [[339, 324]],
#
#         [[340, 324]],
#
#         [[341, 323]],
#
#         [[342, 323]],
#
#         [[343, 322]],
#
#         [[342, 321]],
#
#         [[343, 320]],
#
#         [[342, 319]],
#
#         [[341, 318]],
#
#         [[340, 318]],
#
#         [[339, 317]],
#
#         [[338, 316]],
#
#         [[337, 316]],
#
#         [[336, 315]],
#
#         [[335, 315]],
#
#         [[334, 315]],
#
#         [[333, 314]],
#
#         [[332, 314]],
#
#         [[331, 314]],
#
#         [[330, 314]],
#
#         [[329, 314]],
#
#         [[328, 314]]], dtype=int32),
#  array([[[349, 296]],
#
#         [[348, 297]],
#
#         [[347, 297]],
#
#         ...,
#
#         [[352, 297]],
#
#         [[351, 296]],
#
#         [[350, 296]]], dtype=int32),
#  array([[[ 52, 288]],
#
#         [[ 53, 289]],
#
#         [[ 54, 290]],
#
#         [[ 54, 289]],
#
#         [[ 53, 288]]], dtype=int32),
#  array([[[ 26, 266]],
#
#         [[ 27, 267]],
#
#         [[ 28, 266]],
#
#         [[ 27, 266]]], dtype=int32),
#  array([[[ 14, 259]],
#
#         [[ 15, 259]],
#
#         [[ 16, 260]],
#
#         [[ 17, 260]],
#
#         [[ 18, 261]],
#
#         [[ 19, 261]],
#
#         [[ 20, 261]],
#
#         [[ 21, 261]],
#
#         [[ 22, 262]],
#
#         [[ 23, 262]],
#
#         [[ 24, 262]],
#
#         [[ 25, 263]],
#
#         [[ 26, 263]],
#
#         [[ 27, 264]],
#
#         [[ 27, 263]],
#
#         [[ 26, 263]],
#
#         [[ 25, 263]],
#
#         [[ 24, 262]],
#
#         [[ 23, 262]],
#
#         [[ 22, 262]],
#
#         [[ 21, 261]],
#
#         [[ 20, 261]],
#
#         [[ 19, 261]],
#
#         [[ 18, 260]],
#
#         [[ 17, 260]],
#
#         [[ 16, 259]],
#
#         [[ 15, 259]]], dtype=int32),
#  array([[[591, 116]],
#
#         [[592, 116]],
#
#         [[593, 117]],
#
#         [[594, 117]],
#
#         [[595, 118]],
#
#         [[596, 118]],
#
#         [[597, 118]],
#
#         [[596, 118]],
#
#         [[595, 117]],
#
#         [[594, 117]],
#
#         [[593, 117]],
#
#         [[592, 116]]], dtype=int32),
#  array([[[144,  51]],
#
#         [[144,  52]],
#
#         [[144,  53]],
#
#         ...,
#
#         [[147,  51]],
#
#         [[146,  51]],
#
#         [[145,  51]]], dtype=int32)]

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-d4fded2c709a> in <module>
# ----> 1 np.contours.size()
#
# D:\Anaconda\envs\fyp\lib\site-packages\numpy\__init__.py in __getattr__(attr)
#     213             else:
#     214                 raise AttributeError("module {!r} has no attribute "
# --> 215                                      "{!r}".format(__name__, attr))
#     216
#     217         def __dir__():
#
# AttributeError: module 'numpy' has no attribute 'contours'
